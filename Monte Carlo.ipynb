# %% [markdown]
# So in lstening to the incredible podcast CodeNewbie I heard an interesting tidbit about learning new launguages from the incredible ... oh no! I can't remember his name, now i feel terrible, or was it the command line heroes podcast? Whelp, now i feel really bad.
#
# Anyhoo, this memorable individual likes to build a monte carlo simulation to learn a new language. Since I'm still learning...well everything so I figured I'd give it a go and luckily my favorite pyhton teacher in the whole world has a tutorial series... so here we go.
#
# All credit to Sentdex over at pythonprogramming.net
#
# !!! Don't run these cells in order, they each contain mostly the same code with minor iterations. !!!

# %%
# One
# creating a dice or two

import random

def rollDice():
    roll = random.randint(1,100)
    return roll

# Quick dice test or 100

x = 0
while x < 100:
    results = rollDice()
    print(results)
    x += 1
# Out:
# 26
# 35
# 11
# 38
# 65
# 11
# 84
# 35
# 36
# 72
# 36
# 87
# 19
# 60
# 12
# 99
# 70
# 14
# 25
# 6
# 3
# 79
# 16
# 56
# 41
# 71
# 40
# 78
# 14
# 89
# 12
# 98
# 49
# 41
# 27
# 14
# 70
# 38
# 88
# 61
# 7
# 100
# 2
# 16
# 46
# 53
# 85
# 13
# 90
# 3
# 24
# 5
# 84
# 3
# 82
# 2
# 21
# 65
# 19
# 29
# 24
# 30
# 79
# 96
# 13
# 32
# 18
# 12
# 28
# 66
# 34
# 30
# 1
# 81
# 86
# 88
# 42
# 2
# 69
# 77
# 52
# 87
# 64
# 7
# 71
# 98
# 52
# 88
# 12
# 3
# 24
# 44
# 72
# 14
# 78
# 35
# 95
# 15
# 72
# 6

# %%
# Two
# turning the dice roll into a monte carlo generator

import random

# Simple win/loss dice roll
def rollDice():
    roll = random.randint(1,100)
    
    if roll == 100:
        print(roll, " Max loss, suck it!")
        return False
    elif roll <= 50:
        print(roll, " Nope, thats a loss.")
        return False
    elif 100 > roll >= 50:
        print(roll," Winner Winner Chicken Dinner!")
        return True
    
# Simple bettor, betting the same amount each time.
def simple_bettor(funds,initial_wager,wager_count):
        value = funds
        wager = initial_wager
        
        currentWager = 0
        
        while currentWager < wager_count:
            if rollDice():
                value += wager
            else:
                value -= wager
                
            currentWager += 1
            print("Funds: ", value)
            
simple_bettor(10000,100,100)
# Out:
# 46  Nope, thats a loss.
# Funds:  9900
# 6  Nope, thats a loss.
# Funds:  9800
# 65  Winner Winner Chicken Dinner!
# Funds:  9900
# 95  Winner Winner Chicken Dinner!
# Funds:  10000
# 73  Winner Winner Chicken Dinner!
# Funds:  10100
# 37  Nope, thats a loss.
# Funds:  10000
# 62  Winner Winner Chicken Dinner!
# Funds:  10100
# 16  Nope, thats a loss.
# Funds:  10000
# 58  Winner Winner Chicken Dinner!
# Funds:  10100
# 70  Winner Winner Chicken Dinner!
# Funds:  10200
# 39  Nope, thats a loss.
# Funds:  10100
# 76  Winner Winner Chicken Dinner!
# Funds:  10200
# 34  Nope, thats a loss.
# Funds:  10100
# 24  Nope, thats a loss.
# Funds:  10000
# 23  Nope, thats a loss.
# Funds:  9900
# 86  Winner Winner Chicken Dinner!
# Funds:  10000
# 35  Nope, thats a loss.
# Funds:  9900
# 95  Winner Winner Chicken Dinner!
# Funds:  10000
# 90  Winner Winner Chicken Dinner!
# Funds:  10100
# 99  Winner Winner Chicken Dinner!
# Funds:  10200
# 8  Nope, thats a loss.
# Funds:  10100
# ...

# %%
# Three
# lets see some longer term outcomes for our bettor

import random

# Simple win/loss dice roll
def rollDice():
    roll = random.randint(1,100)
    
    if roll == 100:
        #print(roll, " Max loss, suck it!")
        return False
    elif roll <= 50:
        #print(roll, " Nope, thats a loss.")
        return False
    elif 100 > roll >= 50:
        #print(roll," Winner Winner Chicken Dinner!")
        return True
    
# Simple bettor, betting the same amount each time.
def simple_bettor(funds,initial_wager,wager_count):
        value = funds
        wager = initial_wager
        
        currentWager = 0
        
        while currentWager < wager_count:
            if rollDice():
                value += wager
            else:
                value -= wager
                
            currentWager += 1
            
        # slight change to reduce spam
        if value < 0:
            value = "Broke!"
        print("Funds: ", value)
            
# Big spender on the floor!
x = 0

while x < 100:
    simple_bettor(10000,100,10000)
    x += 1
# Out:
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  600
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  2000
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  5600
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  15000
# Funds:  Broke!
# Funds:  Broke!
# Funds:  400
# Funds:  Broke!
# Funds:  3000
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  7200
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  800
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  Broke!
# Funds:  8200
# Funds:  Broke!
# Funds:  9800
# Funds:  Broke!
# Funds:  Broke!
# ...

# %%
# Four
# Plotting time!
# %matplotlib inline
import random
import matplotlib
import matplotlib.pyplot as plt

# Dice rollerino
def roll_dice():
    roll = random.randint(1,100)
    
    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll > 50:
        return True
    
# Simple bettor making the same bet every wager
def simple_bettor(funds, initial_wager, wager_count):
    value = funds
    wager = initial_wager
    
    # wager X
    wX = []
    
    # value Y
    vY = []
    
    # to avoid confusion we start at 1
    currentWager = 1
    
    while currentWager <= wager_count:
        if roll_dice():
            value += wager
            wX.append(currentWager)
            vY.append(value)
        else:
            value -= wager
            wX.append(currentWager)
            vY.append(value)
            
        currentWager += 1
        
    #if value < 0:
    #    value = "Broke!"
    #print(funds, value)
    
    plt.plot(wX,vY)
    
# Increasing wager_count gives more interesting/obvious results but it can hurt your CPU and takes a moment.    
x = 0        
while x < 100:
    simple_bettor(10000,100,10000)
    x += 1
    
plt.ylabel("Account Value")
plt.xlabel("Wager Count")
plt.show()

# %%
# Five
# Plotting a doubler!

import random
import matplotlib
import matplotlib.pyplot as plt

# Dice rollerino
def roll_dice():
    roll = random.randint(1,100)
    
    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll > 50:
        return True

# 
def doubler_bettor(funds, initial_wager, wager_count):
    value = funds
    wager = initial_wager
    
    wX = []
    vY = []
    
    current_wager = 1
    prev_wager = 'win'
    prev_wager_amount = initial_wager
    
    while current_wager <= wager_count:
        if prev_wager == 'win':
            #print("We won the last wager, yay!")
            if roll_dice():
                value += wager
                #print(value)
                wX.append(current_wager)
                vY.append(value)
            else:
                value -= wager
                prev_wager = 'loss'
                #print(value)
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                
                if value < 0:
                    #print("we went broke after",current_wager,"bets.")
                    break
                    
                    
        elif prev_wager == "loss":
            #print("We lost the last bet so lets double!")
            if roll_dice():
                wager = prev_wager_amount * 2
                #print("We won", wager)
                value += wager
                #print(value)
                wager = initial_wager
                prev_wager = "win"
                wX.append(current_wager)
                vY.append(value)
            else:
                wager = prev_wager_amount * 2
                #print("We lost", wager)
                value -= wager
                if value < 0:
                    #print("We went broke after",current_wager,"bets")
                    break
                    
                #print(value)
                prev_wager = "loss"
                
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                
        current_wager += 1
        
    print(value)
    plt.plot(wX,vY)
    
doubler_bettor(10000,100,1000)
plt.ylabel("Account Value")
plt.xlabel("Wager Count")
plt.show()
# Out:
# -2400

# %%
# Six
# Better bettor statistics

import random
import matplotlib
import matplotlib.pyplot as plt
import time

# Dice rollerino
def roll_dice():
    roll = random.randint(1,100)
    
    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll > 50:
        return True

# double down on losses
def doubler_bettor(funds, initial_wager, wager_count):
    global broke_count
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    current_wager = 1
    prev_wager = 'win'
    prev_wager_amount = initial_wager
    
    while current_wager <= wager_count:
        if prev_wager == 'win':
            if roll_dice():
                value += wager
                wX.append(current_wager)
                vY.append(value)
            else:
                value -= wager
                prev_wager = 'loss'
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value < 0:
                    broke_count += 1
                    break           
        elif prev_wager == "loss":
            if roll_dice():
                wager = prev_wager_amount * 2
                value += wager
                wager = initial_wager
                prev_wager = "win"
                wX.append(current_wager)
                vY.append(value)
            else:
                wager = prev_wager_amount * 2
                value -= wager
                prev_wager = "loss"
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value < 0:
                    broke_count += 1
                    break
                                 
        current_wager += 1
        
    plt.plot(wX,vY)

xx = 0
broke_count = 0

# note to self, xx is number of bettors generated, bettor is (starting cash, stating bet, number of bets)
while xx < 100:
    doubler_bettor(10000,100,1000)
    xx += 1
    
print("Death rate: ", (broke_count/float(xx)) * 100)
print("Survival rate: ", 100 - ((broke_count/float(xx)) * 100))
    
#plt.ylabel("Account Value")
#plt.xlabel("Wager Count")
plt.axhline(0,color='r')
plt.show()
# Out:
# Death rate:  80.0
# Survival rate:  20.0

# %%
# Comparing simple to doubler bettors

import random
import matplotlib
import matplotlib.pyplot as plt
import time

# Dice rollerino
def roll_dice():
    roll = random.randint(1,100)
    
    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll > 50:
        return True

# double down on losses
def doubler_bettor(funds, initial_wager, wager_count):
    global broke_count
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    current_wager = 1
    prev_wager = 'win'
    prev_wager_amount = initial_wager
    
    while current_wager <= wager_count:
        if prev_wager == 'win':
            if roll_dice():
                value += wager
                wX.append(current_wager)
                vY.append(value)
            else:
                value -= wager
                prev_wager = 'loss'
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value < 0:
                    broke_count += 1
                    break           
        elif prev_wager == "loss":
            if roll_dice():
                wager = prev_wager_amount * 2
                value += wager
                wager = initial_wager
                prev_wager = "win"
                wX.append(current_wager)
                vY.append(value)
            else:
                wager = prev_wager_amount * 2
                value -= wager
                prev_wager = "loss"
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value < 0:
                    broke_count += 1
                    break
                                 
        current_wager += 1
        
    plt.plot(wX,vY)
    
# Simple bettor making the same bet every wager
def simple_bettor(funds, initial_wager, wager_count):
    global broke_count
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    currentWager = 1
    
    while currentWager <= wager_count:
        if roll_dice():
            value += wager
            wX.append(currentWager)
            vY.append(value)
        else:
            value -= wager
            wX.append(currentWager)
            vY.append(value)
            
        currentWager += 1
        
    if value < 0:
        value = "Broke!"
        broke_count += 1
    
    plt.plot(wX,vY)


xx = 0
broke_count = 0

# note to self, xx is number of bettors generated, bettor is (starting cash, stating bet, number of bets)
while xx < 100:
    #doubler_bettor(10000,100,1000)
    simple_bettor(10000,100,10000)
    xx += 1
    
print("Death rate: ", (broke_count/float(xx)) * 100)
print("Survival rate: ", 100 - ((broke_count/float(xx)) * 100))
    
plt.ylabel("Account Value")
plt.xlabel("Wager Count")
plt.axhline(0,color='r')
plt.axhline(10000,color='r')
plt.show()
# Out:
# Death rate:  80.0
# Survival rate:  20.0

# %%
# Seven
# Graphing the comparison between simple and doubler bettors

import random
import matplotlib
import matplotlib.pyplot as plt
import time

sample_size = 1000
starting_funds = 10000
wager_size = 100
wager_count = 10000

# Dice rollerino
def roll_dice():
    roll = random.randint(1,100)
    
    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll > 50:
        return True

# double down on losses
def doubler_bettor(funds, initial_wager, wager_count):
    global broke_count
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    current_wager = 1
    prev_wager = 'win'
    prev_wager_amount = initial_wager
    
    while current_wager <= wager_count:
        if prev_wager == 'win':
            if roll_dice():
                value += wager
                wX.append(current_wager)
                vY.append(value)
            else:
                value -= wager
                prev_wager = 'loss'
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value < 0:
                    broke_count += 1
                    break           
        elif prev_wager == "loss":
            if roll_dice():
                wager = prev_wager_amount * 2
                value += wager
                wager = initial_wager
                prev_wager = "win"
                wX.append(current_wager)
                vY.append(value)
            else:
                wager = prev_wager_amount * 2
                value -= wager
                prev_wager = "loss"
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value < 0:
                    broke_count += 1
                    break
                                 
        current_wager += 1
        
    plt.plot(wX,vY,'c')
    
# Simple bettor making the same bet every wager
def simple_bettor(funds, initial_wager, wager_count):
    global broke_count
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    currentWager = 1
    
    while currentWager <= wager_count:
        if roll_dice():
            value += wager
            wX.append(currentWager)
            vY.append(value)
        else:
            value -= wager
            wX.append(currentWager)
            vY.append(value)
            
        currentWager += 1
        
    if value < 0:
        value = "Broke!"
        broke_count += 1
    
    plt.plot(wX,vY,'k')


xx = 0
broke_count = 0

while xx < sample_size:
    doubler_bettor(starting_funds,wager_size,wager_count)
    simple_bettor(starting_funds,wager_size,wager_count)
    xx += 1
    
#print("Death rate: ", (broke_count/float(xx)) * 100)
#print("Survival rate: ", 100 - ((broke_count/float(xx)) * 100))
    
plt.ylabel("Account Value")
plt.xlabel("Wager Count")
plt.axhline(0,color='r')
plt.axhline(10000,color='r')
plt.show()

# %%
# Nine
# Fixing the debt issue

import random
import matplotlib
import matplotlib.pyplot as plt
import time

sample_size = 100
starting_funds = 10000
wager_size = 100
wager_count = 1000

# Dice rollerino
def roll_dice():
    roll = random.randint(1,100)
    
    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll > 50:
        return True

# double down on losses
def doubler_bettor(funds, initial_wager, wager_count, color):
    global broke_count
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    current_wager = 1
    prev_wager = 'win'
    prev_wager_amount = initial_wager
    
    while current_wager <= wager_count:
        if prev_wager == 'win':
            if roll_dice():
                value += wager
                wX.append(current_wager)
                vY.append(value)
            else:
                value -= wager
                prev_wager = 'loss'
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value <= 0:
                    broke_count += 1
                    break           
        elif prev_wager == "loss":
            if roll_dice():
                wager = prev_wager_amount * 2
                if (value - wager) < 0:
                    wager = value
                value += wager
                wager = initial_wager
                prev_wager = "win"
                wX.append(current_wager)
                vY.append(value)
            else:
                wager = prev_wager_amount * 2
                if (value - wager) < 0:
                    wager = value
                value -= wager
                prev_wager = "loss"
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value <= 0:
                    broke_count += 1
                    break
                                 
        current_wager += 1
        
    plt.plot(wX,vY, color)
    
# Simple bettor making the same bet every wager
def simple_bettor(funds, initial_wager, wager_count, color):
    global broke_count
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    currentWager = 1
    
    while currentWager <= wager_count:
        if roll_dice():
            value += wager
            wX.append(currentWager)
            vY.append(value)
        else:
            value -= wager
            wX.append(currentWager)
            vY.append(value)
            
        currentWager += 1
        
    if value <= 0:
        value = "Broke!"
        broke_count += 1
    
    plt.plot(wX,vY,color)


xx = 0
broke_count = 0

while xx < sample_size:
    doubler_bettor(starting_funds,wager_size,wager_count, 'c')
    simple_bettor(starting_funds,wager_size,wager_count, 'k')
    xx += 1
    
#print("Death rate: ", (broke_count/float(xx)) * 100)
#print("Survival rate: ", 100 - ((broke_count/float(xx)) * 100))
    
plt.ylabel("Account Value")
plt.xlabel("Wager Count")
plt.axhline(0,color='r')
plt.axhline(starting_funds,color='r')
plt.show()

# %%
# Ten
# Analyzing results

# %matplotlib inline
import random
import matplotlib
import matplotlib.pyplot as plt
import time

matplotlib.rcParams['figure.figsize'] = [18,6]

sample_size = 100
starting_funds = 10000
wager_size = 100
wager_count = 1000

# Dice rollerino
def roll_dice():
    roll = random.randint(1,100)
    
    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll > 50:
        return True

# double down on losses
def doubler_bettor(funds, initial_wager, wager_count, color):
    global doubler_busts
    global doubler_profits
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    current_wager = 1
    prev_wager = 'win'
    prev_wager_amount = initial_wager
    
    while current_wager <= wager_count:
        if prev_wager == 'win':
            if roll_dice():
                value += wager
                wX.append(current_wager)
                vY.append(value)
            else:
                value -= wager
                prev_wager = 'loss'
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value <= 0:
                    doubler_busts += 1
                    break           
        elif prev_wager == "loss":
            if roll_dice():
                wager = prev_wager_amount * 2
                if (value - wager) < 0:
                    wager = value
                value += wager
                wager = initial_wager
                prev_wager = "win"
                wX.append(current_wager)
                vY.append(value)
            else:
                wager = prev_wager_amount * 2
                if (value - wager) < 0:
                    wager = value
                value -= wager
                prev_wager = "loss"
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value <= 0:
                    doubler_busts += 1
                    break
                                 
        current_wager += 1
        
    plt.plot(wX,vY, color)
    if value > funds:
        doubler_profits += 1
    
# Simple bettor making the same bet every wager
def simple_bettor(funds, initial_wager, wager_count, color):
    global simple_busts
    global simple_profits
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    currentWager = 1
    
    while currentWager <= wager_count:
        if roll_dice():
            value += wager
            wX.append(currentWager)
            vY.append(value)
        else:
            value -= wager
            wX.append(currentWager)
            vY.append(value)
            
        currentWager += 1
        
    if value <= 0:
        value = 0
        simple_busts += 1
    
    plt.plot(wX,vY,color)
    if value > funds:
        value = 0
        simple_profits += 1

    
xx = 0
broke_count = 0
doubler_busts = 0.0
simple_busts = 0.0
doubler_profits = 0.0
simple_profits = 0.0

while xx < sample_size:
    doubler_bettor(starting_funds,wager_size,wager_count, 'c')
    simple_bettor(starting_funds,wager_size,wager_count, 'k')
    xx += 1
    
print("Simple bettor bust chance:", (simple_busts/sample_size) * 100.00)
print("Doubler bettor bust chance:", (doubler_busts/sample_size) * 100.00)
print("Simple bettor profit chance:", (simple_profits/sample_size) * 100.00)
print("Doubler bettor profit chance:", (doubler_profits/sample_size) * 100.00)
    
plt.ylabel("Account Value")
plt.xlabel("Wager Count")
plt.axhline(0,color='r')
plt.axhline(starting_funds,color='r')
plt.show()
# Out:
# Simple bettor bust chance: 1.0
# Doubler bettor bust chance: 89.0
# Simple bettor profit chance: 20.0
# Doubler bettor profit chance: 11.0

# %%
# Eleven
# Finding the best multiple

import random
import matplotlib
import matplotlib.pyplot as plt
import time

matplotlib.rcParams['figure.figsize'] = [18,6]

lower_bust = 31.235
higher_profit = 63.208

sample_size = 1000
starting_funds = 10000
wager_size = 100
wager_count = 100

# Dice rollerino
def roll_dice():
    roll = random.randint(1,100)
    
    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll > 50:
        return True

    
def multiple_bettor(funds, initial_wager, wager_count, color):
    global multiple_busts
    global multiple_profits
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    current_wager = 1
    prev_wager = 'win'
    prev_wager_amount = initial_wager
    
    while current_wager <= wager_count:
        if prev_wager == 'win':
            if roll_dice():
                value += wager
                wX.append(current_wager)
                vY.append(value)
            else:
                value -= wager
                prev_wager = 'loss'
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value <= 0:
                    multiple_busts += 1
                    break           
        elif prev_wager == "loss":
            if roll_dice():
                wager = prev_wager_amount * random_multiple
                if (value - wager) < 0:
                    wager = value
                value += wager
                wager = initial_wager
                prev_wager = "win"
                wX.append(current_wager)
                vY.append(value)
            else:
                wager = prev_wager_amount * random_multiple
                if (value - wager) < 0:
                    wager = value
                value -= wager
                prev_wager = "loss"
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value <= 0:
                    multiple_busts += 1
                    break
                                 
        current_wager += 1
        
    #plt.plot(wX,vY, color)
    if value > funds:
        multiple_profits += 1
    
      
while True:

    multiple_busts = 0.0
    multiple_profits = 0.0

    multiple_samp_size = 100000
    current_sample = 1
    
    random_multiple = random.uniform(1.0,3.0)
    
    while current_sample <= multiple_samp_size:
        multiple_bettor(starting_funds,wager_size,wager_count, 'c')
        current_sample += 1
        
    if ((multiple_busts/multiple_samp_size) * 100.00 < lower_bust) and ((multiple_profits/multiple_samp_size) * 100 > higher_profit):
        print("###############")
        print("Sample: ", current_sample)
        print("Found a winner, multiple was",random_multiple)
        print("Lower bust to beat", lower_bust)
        print("Higher profit rate to beat", higher_profit)
        print("Bust rate: ", (multiple_busts/multiple_samp_size) * 100.00)
        print("Profit rate: ", (multiple_profits/multiple_samp_size) * 100.00)
    
    else:
        pass
# Out:
# ###############
# Sample:  100001
# Found a winner, multiple was 1.6207416056908859
# Lower bust to beat 31.235
# Higher profit rate to beat 63.208
# Bust rate:  10.646
# Profit rate:  65.077
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-3d650bda5c06> in <module>
#      96
#      97     while current_sample <= multiple_samp_size:
# ---> 98         multiple_bettor(starting_funds,wager_size,wager_count, 'c')
#      99         current_sample += 1
#     100
#
# <ipython-input-6-3d650bda5c06> in multiple_bettor(funds, initial_wager, wager_count, color)
#      42     while current_wager <= wager_count:
#      43         if prev_wager == 'win':
# ---> 44             if roll_dice():
#      45                 value += wager
#      46                 wX.append(current_wager)
#
# KeyboardInterrupt:

# %%
# Thirteen
# D'Alembert strategy

import random
import matplotlib
import matplotlib.pyplot as plt
import time

matplotlib.rcParams['figure.figsize'] = [18,6]

sample_size = 1000
starting_funds = 10000
wager_size = 100
wager_count = 100

lower_bust = 31.235
higher_profit = 63.208


# Dice rollerino
def roll_dice():
    roll = random.randint(1,100)
    
    if roll == 100:
        return False
    elif roll <= 50:
        return False
    elif 100 > roll > 50:
        return True


# D'Alembert bettor
def dAlembert(funds, initial_wager, wager_count, color):
    global da_busts
    global da_profits
    
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    current_wager = 1
    prev_wager = 'win'
    prev_wager_amount = initial_wager
    
    while current_wager <= wager_count:
        if prev_wager == 'win':
            if wager == initial_wager:
                pass
            else:
                wager -= initial_wager
                
            if roll_dice():
                value += wager
                wX.append(current_wager)
                vY.append(value)
                prev_wager_amount = wager
            else:
                value -= wager
                prev_wager = 'loss'
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value <= 0:
                    da_busts += 1
                    break
                    
        elif prev_wager == 'loss':
                wager = prev_wager_amount + initial_wager
                if(value - wager) <= 0:
                    wager = value
                    
                if roll_dice():
                    value += wager
                    prev_wager = 'win'
                    wX.append(current_wager)
                    vY.append(value)
                else:
                    value -= wager
                    prev_wager = 'loss'
                    prev_wager_amount = wager
                    wX.append(current_wager)
                    vY.append(value)                    
                    if value <= 0:
                        da_busts += 1
                        break
                        
        current_wager += 1
        
    plt.plot(wX,vY)
        
    if value > funds:
        da_profits += 1 

x = 0
        
while x < 1:        
        
    da_busts = 0
    da_profits = 0
    da_sample_size = 10000
    current_sample = 1
    
    while current_sample <= da_sample_size: 
        dAlembert(10000, 100, 10000, 'c')
        current_sample += 1
        
    #if ((da_busts / da_sample_size) * 100.00 < lower_bust) and ((da_profits / da_sample_size) * 100.00 > higher_profit):
    print("###############")
    print("Lower bust to beat", lower_bust)
    print("Higher profit rate to beat", higher_profit)
    print("Bust rate: ", (multiple_busts/multiple_samp_size) * 100.00)
    print("Profit rate: ", (multiple_profits/multiple_samp_size) * 100.00)    
    
    x += 1
    
plt.show()
# Out:
# ###############
# Lower bust to beat 31.235
# Higher profit rate to beat 63.208
# Bust rate:  10.825999999999999
# Profit rate:  5.044

# %%
# creating a fair dice roll (50/50)
# applying new dice to new 'doubler' bettor using best multiplier (1.75)
# run it a few times, see what we get

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import random

matplotlib.rcParams['figure.figsize'] = [18,6]

def roll_dice():
    
    roll = random.randint(1,100)
    
    if roll <= 50:
        return False
    elif roll >= 51:
        return True
    

def multiple_bettor_2(funds, initial_wager, wager_count, multiple, color):
    global ROI
    global multiple_busts
    global multiple_profits
    
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    current_wager = 1
    prev_wager = 'win'
    prev_wager_amount = initial_wager
    
    while current_wager <= wager_count:
        if prev_wager == 'win':
            if roll_dice():
                value += wager
                wX.append(current_wager)
                vY.append(value)
            else:
                value -= wager
                previous_wager = 'loss'
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value <= 0:
                    multiple_busts += 1
                    break
        elif prev_wager == 'loss':
            if rollDice():
                wager = prev_wager_amount * multiple
                if (value - wager) <= 0:
                    wager = value
                value += wager
                wager = initial_wager
                prev_wager = 'win'
                wX.append(current_wager)
                vY.append(value)
            else:
                wager = prev_wager_amount * multiple
                if (value - wager) <= 0:
                    wager = value
                value -= wager
                prev_wager = 'loss'
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value <= 0:
                    multiple_busts += 1
                    break
                    
        current_wager += 1
        
    ROI += value
    
    plt.plot(wX,vY)
    
    if value > funds:
        multiple_profits += 1
        

starting_funds = 10000
wager_size = 100
wager_count = 10000       
multiple_sample_size = 100000

last_bust_rate = 31.677
last_profit_rate = 47.451
last_diff = 2563200

# 1.75, bust:31.677, profit:47.451, diff:2563200

multiple_busts = 0.0
multiple_profits = 0.0
ROI = 0

counter = 1

while counter <= multiple_sample_size:
    multiple_bettor_2(starting_funds, wager_size, wager_count, 1.75, 'c')
    percentage = (counter / multiple_sample_size) * 100.00
    if percentage % 1 == 0:
        print(int(percentage),"% sample complete")
    counter += 1
    
print("Total amount invested: ", multiple_sample_size * starting_funds)
print("Total return: ", ROI)
print("Difference: ", ROI - (multiple_sample_size * starting_funds))
print("Bust rate: ", (multiple_busts/multiple_sample_size) * 100.00)
print("Profit rate: ", (multiple_profits/multiple_sample_size) * 100.00)
        
plt.ylabel("Account Value")
plt.xlabel("Wager Count")
plt.axhline(starting_funds,color='r')
plt.show()

# %%
# Sixteen
# Comparing profitability

#%matplotlib inline
#import matplotlib
#import matplotlib.pyplot as plt
import random

#matplotlib.rcParams['figure.figsize'] = [18,6]

def roll_dice():
    
    roll = random.randint(1,100)
    
    if roll <= 50:
        return False
    elif roll >= 51:
        return True


def dAlembert(funds, initial_wager, wager_count, color):
    global Ret
    global da_busts
    global da_profits
    
    value = funds
    wager = initial_wager
    #wX = []
    #vY = []
    current_wager = 1
    prev_wager = 'win'
    prev_wager_amount = initial_wager
    
    while current_wager <= wager_count:
        if prev_wager == 'win':
            if wager == initial_wager:
                pass
            else:
                wager -= initial_wager
                
            if roll_dice():
                value += wager
                #wX.append(current_wager)
                #vY.append(value)
                prev_wager_amount = wager
            else:
                value -= wager
                prev_wager = 'loss'
                prev_wager_amount = wager
                #wX.append(current_wager)
                #vY.append(value)
                if value <= 0:
                    da_busts += 1
                    break
                    
        elif prev_wager == 'loss':
                wager = prev_wager_amount + initial_wager
                if(value - wager) <= 0:
                    wager = value
                    
                if roll_dice():
                    value += wager
                    prev_wager = 'win'
                    #wX.append(current_wager)
                    #vY.append(value)
                else:
                    value -= wager
                    prev_wager = 'loss'
                    prev_wager_amount = wager
                    #wX.append(current_wager)
                    #vY.append(value)                    
                    if value <= 0:
                        da_busts += 1
                        break
                        
        current_wager += 1
        
    #plt.plot(wX,vY)
        
    if value > funds:
        da_profits += 1 
        
    Ret += value
        

starting_funds = 10000

while True:
    #wager_size = 100
    #wager_count = 100000
    
    wager_size = random.uniform(1.0,1000.00)
    wager_count = random.uniform(10.0,10000)
    
    multiple_busts = 0.0
    multiple_profits = 0.0
    
    da_busts = 0.0
    da_profits = 0.0
    sample_size = 10000
    Ret = 0

    counter = 1

    while counter <= sample_size:
        dAlembert(starting_funds, wager_size, wager_count, 'c')
        counter += 1
        
    ROI = Ret - (sample_size * starting_funds)
    total_invested = sample_size * starting_funds
    
    percent_ROI = (ROI / total_invested) * 100.00
    
    wager_size_percent = (wager_size / starting_funds) * 100.00
    
    if percent_ROI > 1.000:
        print("_________________________________________")
        print("Total amount invested: ", sample_size * starting_funds)
        print("Total return: ", int(Ret))
        print("ROI: ", round((Ret - (sample_size * starting_funds)), 2))
        print("Percent ROI: ", round(percent_ROI, 2))
        print("Bust rate: ", round(((da_busts/sample_size) * 100.00), 2))
        print("Profit rate: ", round(((da_profits/sample_size) * 100.00), 2))
        print("Wager size: ", int(wager_size))
        print("Wager count: ", int(wager_count))
        print("Wager sizer percentage: ", round(wager_size_percent, 2))
        
        save_file = open("MonteCarloLiberal.csv","a")
        save_line = "\n"+str(percent_ROI)+","+str(wager_size_percent)+","+str(wager_count)+",g"
        save_file.write(save_line)
        save_file.close()
        
    elif percent_ROI > -1.000:
        print("_________________________________________")
        print("Total amount invested: ", sample_size * starting_funds)
        print("Total return: ", int(Ret))
        print("ROI: ", round((Ret - (sample_size * starting_funds)), 2))
        print("Percent ROI: ", round(percent_ROI, 2))
        print("Bust rate: ", round(((da_busts/sample_size) * 100.00), 2))
        print("Profit rate: ", round(((da_profits/sample_size) * 100.00), 2))
        print("Wager size: ", int(wager_size))
        print("Wager count: ", int(wager_count))
        print("Wager sizer percentage: ", round(wager_size_percent, 2))
        
        save_file = open("MonteCarloLiberal.csv","a")
        save_line = "\n"+str(percent_ROI)+","+str(wager_size_percent)+","+str(wager_count)+",r"
        save_file.write(save_line)
        save_file.close()
        
'''        
plt.ylabel("Account Value")
plt.xlabel("Wager Count")
plt.axhline(starting_funds,color='r')
plt.show()
'''
# Out:
# _________________________________________
# Total amount invested:  100000000
# Total return:  104413016
# ROI:  4413016.38
# Percent ROI:  4.41
# Bust rate:  95.78
# Profit rate:  4.21
# Wager size:  192
# Wager count:  3744
# Wager sizer percentage:  1.93
# _________________________________________
# Total amount invested:  100000000
# Total return:  103606884
# ROI:  3606884.61
# Percent ROI:  3.61
# Bust rate:  97.83
# Profit rate:  2.16
# Wager size:  678
# Wager count:  2213
# Wager sizer percentage:  6.78
# _________________________________________
# Total amount invested:  100000000
# Total return:  101658827
# ROI:  1658827.01
# Percent ROI:  1.66
# Bust rate:  99.29
# Profit rate:  0.71
# Wager size:  531
# Wager count:  7831
# Wager sizer percentage:  5.32
# _________________________________________
# Total amount invested:  100000000
# Total return:  99589629
# ROI:  -410370.15
# Percent ROI:  -0.41
# Bust rate:  96.53
# Profit rate:  3.45
# Wager size:  331
# ...

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import csv

def graph():
    with open("MonteCarloLiberal.csv","r") as montecarlo:
        data = csv.reader(montecarlo, delimiter=",")
        
        for each_line in data:
            percent_ROI = float(each_line[0])
            wager_size_percent = float(each_line[1])
            wager_count = float(each_line[2])
            plotcolor = each_line[3]
            
            plt.scatter(wager_size_percent, wager_count, color=plotcolor)
            
    plt.show()
    
graph()
