# %%
import random
import matplotlib
import matplotlib.pyplot as plt
import time

matplotlib.rcParams['figure.figsize'] = [18,6]

lower_bust = 31.235
higher_profit = 63.208

sample_size = 1000
starting_funds = 10000
wager_size = 100
wager_count = 100

# %%
# Dice rollerino
def roll_dice():
    
    roll = random.randint(1,100)
    
    if roll <= 50:
        return False
    elif roll >= 51:
        return True

# %%
# Bettor based on the 'doubler' method however uses a calculated betting multiple (1.72)
def multiple_bettor(funds, initial_wager, wager_count, color):
    global multiple_busts
    global multiple_profits
    value = funds
    wager = initial_wager
    wX = []
    vY = []
    current_wager = 1
    prev_wager = 'win'
    prev_wager_amount = initial_wager
    
    while current_wager <= wager_count:
        if prev_wager == 'win':
            if roll_dice():
                value += wager
                wX.append(current_wager)
                vY.append(value)
            else:
                value -= wager
                prev_wager = 'loss'
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value <= 0:
                    multiple_busts += 1
                    break           
        elif prev_wager == "loss":
            if roll_dice():
                wager = prev_wager_amount * random_multiple
                if (value - wager) < 0:
                    wager = value
                value += wager
                wager = initial_wager
                prev_wager = "win"
                wX.append(current_wager)
                vY.append(value)
            else:
                wager = prev_wager_amount * random_multiple
                if (value - wager) < 0:
                    wager = value
                value -= wager
                prev_wager = "loss"
                prev_wager_amount = wager
                wX.append(current_wager)
                vY.append(value)
                if value <= 0:
                    multiple_busts += 1
                    break
                                 
        current_wager += 1
        
    #plt.plot(wX,vY, color)
    if value > funds:
        multiple_profits += 1

# %%
# Comparison system for different multiples

while True:

    multiple_busts = 0.0
    multiple_profits = 0.0

    multiple_samp_size = 100000
    current_sample = 1
    
    # max was changed to 3.0 to speed up run time as no results were recorded > 2.0
    random_multiple = random.uniform(1.0,3.0)
    
    while current_sample <= multiple_samp_size:
        multiple_bettor(starting_funds,wager_size,wager_count, 'c')
        current_sample += 1
        
    if ((multiple_busts/multiple_samp_size) * 100.00 < lower_bust) and ((multiple_profits/multiple_samp_size) * 100 > higher_profit):
        print("###############")
        print("Found a winner, multiple was",random_multiple)
        print("Lower bust to beat", lower_bust)
        print("Higher profit rate to beat", higher_profit)
        print("Bust rate: ", (multiple_busts/multiple_samp_size) * 100.00)
        print("Profit rate: ", (multiple_profits/multiple_samp_size) * 100.00)
        print("###############")
    
    else:
        pass
# Out:
# ###############
# Found a winner, multiple was 1.6615639104270614
# Lower bust to beat 31.235
# Higher profit rate to beat 63.208
# Bust rate:  11.745999999999999
# Profit rate:  67.508
# ###############
# ###############
# Found a winner, multiple was 1.723443589159038
# Lower bust to beat 31.235
# Higher profit rate to beat 63.208
# Bust rate:  16.098000000000003
# Profit rate:  70.91
# ###############
# ###############
# Found a winner, multiple was 1.7250991205614277
# Lower bust to beat 31.235
# Higher profit rate to beat 63.208
# Bust rate:  16.291
# Profit rate:  71.041
# ###############
# ###############
# Found a winner, multiple was 1.9809756415826265
# Lower bust to beat 31.235
# Higher profit rate to beat 63.208
# Bust rate:  30.269000000000002
# Profit rate:  63.641000000000005
# ###############
# ###############
# Found a winner, multiple was 1.617121086215485
# Lower bust to beat 31.235
# Higher profit rate to beat 63.208
# Bust rate:  10.374
# Profit rate:  64.927
# ###############
# ###############
# Found a winner, multiple was 1.6945963268961055
# Lower bust to beat 31.235
# Higher profit rate to beat 63.208
# Bust rate:  13.597999999999999
# Profit rate:  69.62899999999999
# ###############
# ###############
# Found a winner, multiple was 1.8038817655950048
# Lower bust to beat 31.235
# Higher profit rate to beat 63.208
# Bust rate:  20.616
# Profit rate:  66.75
# ###############
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-12fedcc8beeb> in <module>
#      10
#      11     while current_sample <= multiple_samp_size:
# ---> 12         multiple_bettor(starting_funds,wager_size,wager_count, 'c')
#      13         current_sample += 1
#      14
#
# <ipython-input-3-02b15818744c> in multiple_bettor(funds, initial_wager, wager_count, color)
#      13     while current_wager <= wager_count:
#      14         if prev_wager == 'win':
# ---> 15             if roll_dice():
#      16                 value += wager
#      17                 wX.append(current_wager)
#
# KeyboardInterrupt:
